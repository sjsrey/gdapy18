# %% [markdown]
# # Spatial Data Processing with PySAL & Pandas

# %%
# By convention, we use these shorter two-letter names
import pysal as ps
import pandas as pd
import numpy as np
# Out:
# /home/serge/anaconda3/envs/workshop/lib/python3.6/site-packages/pysal/__init__.py:65: VisibleDeprecationWarning: PySAL's API will be changed on 2018-12-31. The last release made with this API is version 1.14.4. A preview of the next API version is provided in the `pysal` 2.0 prelease candidate. The API changes and a guide on how to change imports is provided at https://pysal.org/about
#   ), VisibleDeprecationWarning)

# %% [markdown]
# PySAL has two simple ways to read in data. But, first, you need to get the path from where your notebook is running on your computer to the place the data is. For example, to find where the notebook is running:

# %%
# !pwd # on windows !cd
# Out:
# /home/serge/Dropbox/p/pbpl273/19w/notes/public/content

# %% [markdown]
# PySAL has a command that it uses to get the paths of its example datasets. Let's work with a commonly-used dataset first.

# %%
ps.examples.available()
# Out:
# ['snow_maps',
#  'londonhp',
#  'taz',
#  'geodanet',
#  'nat',
#  'south',
#  'stl',
#  'chicago',
#  'us_income',
#  'Polygon_Holes',
#  'virginia',
#  'columbus',
#  'calemp',
#  'sacramento2',
#  'tokyo',
#  'clearwater',
#  'newHaven',
#  'street_net_pts',
#  'burkitt',
#  'baltim',
#  'wmat',
#  'mexico',
#  'desmith',
#  'Point',
#  '10740',
#  'georgia',
#  'arcgis',
#  'sids2',
#  'juvenile',
#  'Polygon',
#  'book',
#  'networks',
#  'nyc_bikes',
#  'Line']

# %%
ps.examples.explain('us_income')
# Out:
# {'name': 'us_income',
#  'description': 'Nominal per capita income for the lower 48 US states 1929-2009',
#  'explanation': ['* states48.gal: queen contiguity weights in GAL format.',
#   '* us48.dbf: attribute data. (k=8)',
#   '* us48.shp: Polygon shapefile. (n=48)',
#   '* us48.shx: spatial index.',
#   '* usjoin.csv: 48 US states nominal per capita income time series 1929-2009.']}

# %%
csv_path = ps.examples.get_path('usjoin.csv')

# %%
csv_path
# Out:
# '/home/serge/anaconda3/envs/workshop/lib/python3.6/site-packages/pysal/examples/us_income/usjoin.csv'

# %%
f = ps.open(csv_path)
f.header[0:10]
# Out:
# ['Name',
#  'STATE_FIPS',
#  '1929',
#  '1930',
#  '1931',
#  '1932',
#  '1933',
#  '1934',
#  '1935',
#  '1936']

# %%
y2009 = f.by_col('2009')

# %%
y2009
# Out:
# [32274,
#  32077,
#  31493,
#  40902,
#  40093,
#  52736,
#  40135,
#  36565,
#  33086,
#  30987,
#  40933,
#  33174,
#  35983,
#  37036,
#  31250,
#  35151,
#  35268,
#  47159,
#  49590,
#  34280,
#  40920,
#  29318,
#  35106,
#  32699,
#  37057,
#  38009,
#  41882,
#  48123,
#  32197,
#  46844,
#  33564,
#  38672,
#  35018,
#  33708,
#  35210,
#  38827,
#  41283,
#  30835,
#  36499,
#  33512,
#  35674,
#  30107,
#  36752,
#  43211,
#  40619,
#  31843,
#  35676,
#  42504]

# %%
y2009[0:10]
# Out:
# [32274, 32077, 31493, 40902, 40093, 52736, 40135, 36565, 33086, 30987]

# %% [markdown]
# ### Working with shapefiles

# %% [markdown]
# We can also work with local files outside the built-in examples.
#
# To read in a shapefile, we will need the path to the file.

# %%
shp_path = 'data/texas.shp'
print(shp_path)
# Out:
# data/texas.shp

# %% [markdown]
# Then, we open the file using the `ps.open` command:

# %%
f = ps.open(shp_path)

# %% [markdown]
# `f` is what we call a "file handle." That means that it only *points* to the data and provides ways to work with it. By itself, it does not read the whole dataset into memory. To see basic information about the file, we can use a few different methods.
#
# For instance, the header of the file, which contains most of the metadata about the file:

# %%
f.header
# Out:
# {'File Code': 9994,
#  'Unused0': 0,
#  'Unused1': 0,
#  'Unused2': 0,
#  'Unused3': 0,
#  'Unused4': 0,
#  'File Length': 49902,
#  'Version': 1000,
#  'Shape Type': 5,
#  'BBOX Xmin': -106.6495132446289,
#  'BBOX Ymin': 25.845197677612305,
#  'BBOX Xmax': -93.50721740722656,
#  'BBOX Ymax': 36.49387741088867,
#  'BBOX Zmin': 0.0,
#  'BBOX Zmax': 0.0,
#  'BBOX Mmin': 0.0,
#  'BBOX Mmax': 0.0}

# %% [markdown]
# To actually read in the shapes from memory, you can use the following commands:

# %%
f.by_row(14) # gets the 14th shape from the file

# %%
all_polygons = f.read() # reads in all polygons from memory

# %%
all_polygons
# Out:
# [<pysal.cg.shapes.Polygon at 0x7f7a3457b9e8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a3457bba8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a3457b550>,
#  <pysal.cg.shapes.Polygon at 0x7f7a3457b278>,
#  <pysal.cg.shapes.Polygon at 0x7f7a3457bc88>,
#  <pysal.cg.shapes.Polygon at 0x7f7a3457ba58>,
#  <pysal.cg.shapes.Polygon at 0x7f7a3457bd30>,
#  <pysal.cg.shapes.Polygon at 0x7f7a3457bda0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a3457be10>,
#  <pysal.cg.shapes.Polygon at 0x7f7a3457be80>,
#  <pysal.cg.shapes.Polygon at 0x7f7a3457bef0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a3457bf60>,
#  <pysal.cg.shapes.Polygon at 0x7f7a3457bfd0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a3457b4e0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33d02048>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33d020b8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33d02160>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33d021d0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33d02278>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33d022e8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33d02390>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33d02400>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33d024a8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33d02550>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33d025f8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33d02668>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33d02dd8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33d02f28>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33d027b8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33d02cf8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33d02e48>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33d02898>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33d02978>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33d027f0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33d028d0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33d02ac8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33d02da0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33d02710>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33d02780>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33d02ef0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33d02f98>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33d026d8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33d02828>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cba080>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cba128>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cba198>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cba208>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cba278>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cba2e8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cba358>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cba3c8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cba438>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cba4e0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cba550>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cba5c0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cba630>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cba6d8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cba748>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cba780>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cba7f0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cba898>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cba908>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cba978>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cbaa20>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cbaac8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cbab38>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cbaba8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cbac18>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cbac88>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cbad30>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cbada0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cbae10>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cbae80>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cbaef0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cbaf60>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cbafd0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccd080>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccd128>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccd1d0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccd240>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccd2b0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccd320>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccd390>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccd400>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccd4a8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccd518>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccd588>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccd5f8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccd668>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccd6d8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccd748>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccd7b8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccd828>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccd898>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccd908>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccd978>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccd9e8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccda58>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccdb00>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccdb70>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccdc18>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccdc88>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccdcf8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccdd68>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccde10>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccde80>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccdf28>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccdf98>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33ccdfd0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cdd0b8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cdd128>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cdd198>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cdd1d0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cdd240>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cdd2e8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cdd358>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cdd3c8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cdd438>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cdd4a8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cdd518>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cdd588>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cdd5f8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cdd6a0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cdd748>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cdd7b8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cdd828>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cdd898>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cdd8d0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cdd940>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cdd9e8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cdda58>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cddac8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cddb38>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cddba8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cddc18>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cddc88>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cddcf8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cddd68>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cdddd8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cdde48>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cddef0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cddf60>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cddfd0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cff080>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cff0f0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cff160>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cff208>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cff278>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cff2e8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cff358>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cff3c8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cff438>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cff4a8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cff550>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cff5c0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cff630>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cff6a0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cff710>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cff780>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cff7f0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cff860>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cff8d0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cff940>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cff9b0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cff9e8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cffa58>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cffb00>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cffba8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cffc50>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cffcc0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cffd30>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cffda0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cffe10>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cffe80>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cffef0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cfff60>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33cfffd0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7d080>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7d0f0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7d160>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7d1d0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7d240>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7d2b0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7d320>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7d390>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7d400>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7d470>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7d4e0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7d518>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7d588>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7d630>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7d6a0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7d710>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7d780>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7d7f0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7d860>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7d8d0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7d940>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7d9b0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7da20>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7da90>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7db00>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7db70>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7dbe0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7dc50>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7dcc0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7dd30>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7dda0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7de10>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7de80>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7def0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7df60>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c7dfd0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c27048>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c270f0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c27160>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c271d0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c27240>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c272e8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c27358>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c273c8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c27390>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c27518>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c27588>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c275f8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c27668>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c276d8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c27748>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c277b8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c27828>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c27898>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c27908>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c27978>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c279e8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c27a58>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c27ac8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c27b38>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c27ba8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c27c18>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c27da0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c27dd8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c27e10>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c27eb8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c27fd0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c43080>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c43048>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c430b8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c43240>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c432b0>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c43320>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c432e8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c43470>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c434a8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a33c43550>]

# %%
len(all_polygons)
# Out:
# 254

# %% [markdown]
# So, all 254 polygons have been read in from file. These are stored in PySAL shape objects, which can be used by PySAL and can be converted to other Python shape objects.
#
# They typically have a few methods. So, since we've read in polygonal data, we can get some properties about the polygons. Let's just have a look at the first polygon:

# %%
all_polygons[0:5]
# Out:
# [<pysal.cg.shapes.Polygon at 0x7f7a3457b9e8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a3457bba8>,
#  <pysal.cg.shapes.Polygon at 0x7f7a3457b550>,
#  <pysal.cg.shapes.Polygon at 0x7f7a3457b278>,
#  <pysal.cg.shapes.Polygon at 0x7f7a3457bc88>]

# %%
all_polygons[0]

# %%
all_polygons[0].centroid #the centroid of the first polygon
# Out:
# (-100.27156110567945, 36.27508640938005)

# %%
all_polygons[0].area
# Out:
# 0.23682222998468205

# %%
all_polygons[0].perimeter
# Out:
# 1.9582821721538344

# %%
pp = all_polygons[0]

# %%
pp.
# Out:
#   File "<ipython-input-24-46016c123f52>", line 1
#     pp.
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# While in the Jupyter Notebook, you can examine what properties an object has by using the tab key.

# %%
polygon = all_polygons[0]

# %%
polygon. #press tab when the cursor is right after the dot
# Out:
#   File "<ipython-input-26-6ab3d2da4217>", line 1
#     polygon. #press tab when the cursor is right after the dot
#                                                               ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Working with Data Tables

# %%
dbf_path = "data/texas.dbf"
print(dbf_path)
# Out:
# data/texas.dbf

# %% [markdown]
# When you're working with tables of data, like a `csv` or `dbf`, you can extract your data in the following way. Let's open the dbf file we got the path for above.

# %%
f = ps.open(dbf_path)

# %% [markdown]
# Just like with the shapefile, we can examine the header of the dbf file.

# %%
f.header
# Out:
# ['NAME',
#  'STATE_NAME',
#  'STATE_FIPS',
#  'CNTY_FIPS',
#  'FIPS',
#  'STFIPS',
#  'COFIPS',
#  'FIPSNO',
#  'SOUTH',
#  'HR60',
#  'HR70',
#  'HR80',
#  'HR90',
#  'HC60',
#  'HC70',
#  'HC80',
#  'HC90',
#  'PO60',
#  'PO70',
#  'PO80',
#  'PO90',
#  'RD60',
#  'RD70',
#  'RD80',
#  'RD90',
#  'PS60',
#  'PS70',
#  'PS80',
#  'PS90',
#  'UE60',
#  'UE70',
#  'UE80',
#  'UE90',
#  'DV60',
#  'DV70',
#  'DV80',
#  'DV90',
#  'MA60',
#  'MA70',
#  'MA80',
#  'MA90',
#  'POL60',
#  'POL70',
#  'POL80',
#  'POL90',
#  'DNL60',
#  'DNL70',
#  'DNL80',
#  'DNL90',
#  'MFIL59',
#  'MFIL69',
#  'MFIL79',
#  'MFIL89',
#  'FP59',
#  'FP69',
#  'FP79',
#  'FP89',
#  'BLK60',
#  'BLK70',
#  'BLK80',
#  'BLK90',
#  'GI59',
#  'GI69',
#  'GI79',
#  'GI89',
#  'FH60',
#  'FH70',
#  'FH80',
#  'FH90']

# %% [markdown]
# So, the header is a list containing the names of all of the fields we can read.
# If we just wanted to grab the data of interest, `HR90`, we can use either `by_col` or `by_col_array`, depending on the format we want the resulting data in:

# %%
HR90 = f.by_col('HR90')
print(type(HR90).__name__, HR90[0:5])
HR90 = f.by_col_array('HR90')
print(type(HR90).__name__, HR90[0:5])
# Out:
# list [0.0, 0.0, 18.31166453, 0.0, 3.6517674554]
# ndarray [[ 0.        ]
#  [ 0.        ]
#  [18.31166453]
#  [ 0.        ]
#  [ 3.65176746]]

# %% [markdown]
# As you can see, the `by_col` function returns a list of data, with no shape. It can only return one column at a time:

# %%
HRs = f.by_col('HR90', 'HR80')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-76c38231d8a5> in <module>
# ----> 1 HRs = f.by_col('HR90', 'HR80')
#
# TypeError: __call__() takes 2 positional arguments but 3 were given

# %% [markdown]
# This error message is called a "traceback," as you see in the top right, and it usually provides feedback on why the previous command did not execute correctly. Here, you see that one-too-many arguments was provided to `__call__`, which tells us we cannot pass as many arguments as we did to `by_col`.
#
# If you want to read in many columns at once and store them to an array, use `by_col_array`:

# %%
HRs = f.by_col_array('HR90', 'HR80')

# %%
HRs.dtype
# Out:
# dtype('float64')

# %%
HRs[0:10]
# Out:
# array([[ 0.        ,  0.        ],
#        [ 0.        , 10.50199538],
#        [18.31166453,  5.10386362],
#        [ 0.        ,  0.        ],
#        [ 3.65176746, 10.4297038 ],
#        [ 0.        ,  0.        ],
#        [ 0.        , 18.85369532],
#        [ 2.59514448,  6.33617194],
#        [ 0.        ,  0.        ],
#        [ 5.59753708,  6.0331825 ]])

# %% [markdown]
# It is best to use `by_col_array` on data of a single type. That is, if you read in a lot of columns, some of them numbers and some of them strings, all columns will get converted to the same datatype:

# %%
allcolumns = f.by_col_array(['NAME', 'STATE_NAME', 'HR90', 'HR80'])

# %%
allcolumns
# Out:
# array([['Lipscomb', 'Texas', '0.0', '0.0'],
#        ['Sherman', 'Texas', '0.0', '10.501995379'],
#        ['Dallam', 'Texas', '18.31166453', '5.1038636248'],
#        ...,
#        ['Hidalgo', 'Texas', '7.3003167816', '8.2383277607'],
#        ['Willacy', 'Texas', '5.6481219994', '7.6212251119'],
#        ['Cameron', 'Texas', '12.302014455', '11.761321464']], dtype='<U13')

# %%
allcolumns.dtype
# Out:
# dtype('<U13')

# %% [markdown]
# Note that the numerical columns, `HR90` & `HR80` are now considered strings, since they show up with the single tickmarks around them, like `'0.0'`.

# %% [markdown]
# These methods work similarly for `.csv` files as well.

# %% [markdown]
# ### Using Pandas with PySAL

# %% [markdown]
# A new functionality added to PySAL recently allows you to work with shapefile/dbf pairs using Pandas. This *optional* extension is only turned on if you have Pandas installed. The extension is the `ps.pdio` module:

# %%
ps.pdio
# Out:
# <module 'pysal.contrib.pdio' from '/home/serge/anaconda3/envs/workshop/lib/python3.6/site-packages/pysal/contrib/pdio/__init__.py'>

# %% [markdown]
# To use it, you can read in shapefile/dbf pairs using the `ps.pdio.read_files` command.

# %%
shp_path = ps.examples.get_path('NAT.shp')
data_table = ps.pdio.read_files(shp_path)

# %% [markdown]
# This reads in *the entire database table* and adds a column to the end, called `geometry`, that stores the geometries read in from the shapefile.
#
# Now, you can work with it like a standard pandas dataframe.

# %%
data_table.head()
# Out:
#                 NAME  STATE_NAME STATE_FIPS CNTY_FIPS   FIPS  STFIPS  COFIPS  \
# 0  Lake of the Woods   Minnesota         27       077  27077      27      77
# 1              Ferry  Washington         53       019  53019      53      19
# 2            Stevens  Washington         53       065  53065      53      65
# 3           Okanogan  Washington         53       047  53047      53      47
# 4       Pend Oreille  Washington         53       051  53051      53      51
#
#    FIPSNO  SOUTH      HR60                        ...                          \
# 0   27077      0  0.000000                        ...
# 1   53019      0  0.000000                        ...
# 2   53065      0  1.863863                        ...
# 3   53047      0  2.612330                        ...
# 4   53051      0  0.000000                        ...
#
#       BLK90      GI59      GI69      GI79      GI89       FH60  FH70  \
# 0  0.024534  0.285235  0.372336  0.342104  0.336455  11.279621   5.4
# 1  0.317712  0.256158  0.360665  0.361928  0.360640  10.053476   2.6
# 2  0.210030  0.283999  0.394083  0.357566  0.369942   9.258437   5.6
# 3  0.155922  0.258540  0.371218  0.381240  0.394519   9.039900   8.1
# 4  0.134605  0.243263  0.365614  0.358706  0.387848   8.243930   4.1
#
#         FH80       FH90                                           geometry
# 0   5.663881   9.515860  <pysal.cg.shapes.Polygon object at 0x7f7a6eee1...
# 1  10.079576  11.397059  <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 2   6.812127  10.352015  <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 3  10.084926  12.840340  <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 4   7.557643  10.313002  <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
#
# [5 rows x 70 columns]

# %% [markdown]
# The `read_files` function only works on shapefile/dbf pairs. If you need to read in data using CSVs, use pandas directly:

# %%
csv_path = ps.examples.get_path('usjoin.csv')
usjoin = pd.read_csv(csv_path)
#usjoin = ps.pdio.read_files(csv_path) #will not work, not a shp/dbf pair

# %%
usjoin.head()
# Out:
#          Name  STATE_FIPS  1929  1930  1931  1932  1933  1934  1935  1936  \
# 0     Alabama           1   323   267   224   162   166   211   217   251
# 1     Arizona           4   600   520   429   321   308   362   416   462
# 2    Arkansas           5   310   228   215   157   157   187   207   247
# 3  California           6   991   887   749   580   546   603   660   771
# 4    Colorado           8   634   578   471   354   353   368   444   542
#
#    ...     2000   2001   2002   2003   2004   2005   2006   2007   2008   2009
# 0  ...    23471  24467  25161  26065  27665  29097  30634  31988  32819  32274
# 1  ...    25578  26232  26469  27106  28753  30671  32552  33470  33445  32077
# 2  ...    22257  23532  23929  25074  26465  27512  29041  31070  31800  31493
# 3  ...    32275  32750  32900  33801  35663  37463  40169  41943  42377  40902
# 4  ...    32949  34228  33963  34092  35543  37388  39662  41165  41719  40093
#
# [5 rows x 83 columns]

# %% [markdown]
# The nice thing about working with pandas dataframes is that they have very powerful baked-in support for relational-style queries. By this, I mean that it is very easy to find things like:
#
# The number of counties in each state:

# %%
data_table.groupby("STATE_NAME").size()
# Out:
# STATE_NAME
# Alabama                  67
# Arizona                  14
# Arkansas                 75
# California               58
# Colorado                 63
# Connecticut               8
# Delaware                  3
# District of Columbia      1
# Florida                  67
# Georgia                 159
# Idaho                    44
# Illinois                102
# Indiana                  92
# Iowa                     99
# Kansas                  105
# Kentucky                120
# Louisiana                64
# Maine                    16
# Maryland                 24
# Massachusetts            12
# Michigan                 83
# Minnesota                87
# Mississippi              82
# Missouri                115
# Montana                  55
# Nebraska                 93
# Nevada                   17
# New Hampshire            10
# New Jersey               21
# New Mexico               32
# New York                 58
# North Carolina          100
# North Dakota             53
# Ohio                     88
# Oklahoma                 77
# Oregon                   36
# Pennsylvania             67
# Rhode Island              5
# South Carolina           46
# South Dakota             66
# Tennessee                95
# Texas                   254
# Utah                     29
# Vermont                  14
# Virginia                123
# Washington               38
# West Virginia            55
# Wisconsin                70
# Wyoming                  23
# dtype: int64

# %% [markdown]
# Or, to get the rows of the table that are in Arizona, we can use the `query` function of the dataframe:

# %%
data_table.query('STATE_NAME == "Arizona"')
# Out:
#             NAME STATE_NAME STATE_FIPS CNTY_FIPS   FIPS  STFIPS  COFIPS  \
# 1707      Navajo    Arizona         04       017  04017       4      17
# 1708    Coconino    Arizona         04       005  04005       4       5
# 1722      Mohave    Arizona         04       015  04015       4      15
# 1726      Apache    Arizona         04       001  04001       4       1
# 2002     Yavapai    Arizona         04       025  04025       4      25
# 2182        Gila    Arizona         04       007  04007       4       7
# 2262    Maricopa    Arizona         04       013  04013       4      13
# 2311    Greenlee    Arizona         04       011  04011       4      11
# 2326      Graham    Arizona         04       009  04009       4       9
# 2353       Pinal    Arizona         04       021  04021       4      21
# 2499        Pima    Arizona         04       019  04019       4      19
# 2514     Cochise    Arizona         04       003  04003       4       3
# 2615  Santa Cruz    Arizona         04       023  04023       4      23
# 3080      La Paz    Arizona         04       012  04012       4      12
#
#       FIPSNO  SOUTH       HR60  \
# 1707    4017      0   5.263989
# 1708    4005      0   3.185449
# 1722    4015      0   0.000000
# 1726    4001      0  10.951223
# 2002    4025      0   3.458771
# 2182    4007      0   6.473749
# 2262    4013      0   6.179259
# 2311    4011      0   2.896284
# 2326    4009      0   4.746648
# 2353    4021      0  13.828390
# 2499    4019      0   5.520841
# 2514    4003      0   4.845049
# 2615    4023      0   9.252406
# 3080    4012      0   5.046682
#
#                             ...                             BLK90      GI59  \
# 1707                        ...                          0.905251  0.366863
# 1708                        ...                          1.469081  0.301222
# 1722                        ...                          0.324075  0.279339
# 1726                        ...                          0.162361  0.395913
# 2002                        ...                          0.298011  0.289509
# 2182                        ...                          0.246171  0.265294
# 2262                        ...                          3.499221  0.277828
# 2311                        ...                          0.349650  0.177691
# 2326                        ...                          1.890487  0.310256
# 2353                        ...                          3.134586  0.304294
# 2499                        ...                          3.118252  0.268266
# 2514                        ...                          5.201590  0.261208
# 2615                        ...                          0.326863  0.327130
# 3080                        ...                          2.628811  0.271556
#
#           GI69      GI79      GI89       FH60  FH70       FH80       FH90  \
# 1707  0.414135  0.401999  0.445299  13.146998  12.1  13.762783  18.033782
# 1708  0.377785  0.381655  0.403188   9.475171   8.5  11.181563  15.267643
# 1722  0.347150  0.375790  0.374383  11.508554   4.8   7.018268   9.214294
# 1726  0.450552  0.431013  0.489132  15.014738  14.6  18.727548  22.933635
# 2002  0.378195  0.376313  0.384089   9.930032   8.6   7.516372   9.483521
# 2182  0.337519  0.353848  0.386976  10.470261   8.1   9.934237  11.706102
# 2262  0.352374  0.366015  0.372756  10.642382   9.8  11.857260  14.404902
# 2311  0.257158  0.283518  0.337256   9.806115   6.7   5.295110  10.453284
# 2326  0.362926  0.383554  0.408379  11.979335  10.1  11.961367  16.129032
# 2353  0.369974  0.361193  0.400130  10.822965   8.8  10.341699  15.304144
# 2499  0.367218  0.375039  0.392144  11.381626  10.2  12.689768  16.163178
# 2514  0.359500  0.359701  0.399208  10.197573   8.7   9.912732  13.733872
# 2615  0.396807  0.393240  0.413795  19.007213  14.7  15.690913  18.272244
# 3080  0.364110  0.372662  0.405743   9.216414   8.0   9.296093  12.379134
#
#                                                geometry
# 1707  <pysal.cg.shapes.Polygon object at 0x7f7a33210...
# 1708  <pysal.cg.shapes.Polygon object at 0x7f7a33210...
# 1722  <pysal.cg.shapes.Polygon object at 0x7f7a33237...
# 1726  <pysal.cg.shapes.Polygon object at 0x7f7a33237...
# 2002  <pysal.cg.shapes.Polygon object at 0x7f7a330e4...
# 2182  <pysal.cg.shapes.Polygon object at 0x7f7a33026...
# 2262  <pysal.cg.shapes.Polygon object at 0x7f7a32ffa...
# 2311  <pysal.cg.shapes.Polygon object at 0x7f7a32fad...
# 2326  <pysal.cg.shapes.Polygon object at 0x7f7a32f55...
# 2353  <pysal.cg.shapes.Polygon object at 0x7f7a32f09...
# 2499  <pysal.cg.shapes.Polygon object at 0x7f7a32e92...
# 2514  <pysal.cg.shapes.Polygon object at 0x7f7a6c218...
# 2615  <pysal.cg.shapes.Polygon object at 0x7f7a32e0c...
# 3080  <pysal.cg.shapes.Polygon object at 0x7f7a32c59...
#
# [14 rows x 70 columns]

# %% [markdown]
# Behind the scenes, this uses a fast vectorized library, `numexpr`, to essentially do the following.
#
# First, compare each row's `STATE_NAME` column to `'Arizona'` and return `True` if the row matches:

# %%
data_table.STATE_NAME
# Out:
# 0          Minnesota
# 1         Washington
# 2         Washington
# 3         Washington
# 4         Washington
# 5              Idaho
# 6            Montana
# 7            Montana
# 8            Montana
# 9            Montana
# 10           Montana
# 11           Montana
# 12           Montana
# 13      North Dakota
# 14      North Dakota
# 15      North Dakota
# 16      North Dakota
# 17      North Dakota
# 18      North Dakota
# 19      North Dakota
# 20      North Dakota
# 21         Minnesota
# 22         Minnesota
# 23           Montana
# 24           Montana
# 25           Montana
# 26           Montana
# 27        Washington
# 28             Idaho
# 29      North Dakota
#             ...
# 3055    Pennsylvania
# 3056    Pennsylvania
# 3057    Pennsylvania
# 3058    Pennsylvania
# 3059        Illinois
# 3060            Ohio
# 3061        Illinois
# 3062        Illinois
# 3063    Pennsylvania
# 3064            Ohio
# 3065         Indiana
# 3066         Indiana
# 3067         Indiana
# 3068         Indiana
# 3069         Indiana
# 3070        New York
# 3071        Virginia
# 3072        Virginia
# 3073        Virginia
# 3074        Virginia
# 3075        Virginia
# 3076        Virginia
# 3077        Virginia
# 3078        Virginia
# 3079       Wisconsin
# 3080         Arizona
# 3081      New Mexico
# 3082        Virginia
# 3083        Virginia
# 3084         Montana
# Name: STATE_NAME, Length: 3085, dtype: object

# %%
data_table["STATE_NAME"]
# Out:
# 0          Minnesota
# 1         Washington
# 2         Washington
# 3         Washington
# 4         Washington
# 5              Idaho
# 6            Montana
# 7            Montana
# 8            Montana
# 9            Montana
# 10           Montana
# 11           Montana
# 12           Montana
# 13      North Dakota
# 14      North Dakota
# 15      North Dakota
# 16      North Dakota
# 17      North Dakota
# 18      North Dakota
# 19      North Dakota
# 20      North Dakota
# 21         Minnesota
# 22         Minnesota
# 23           Montana
# 24           Montana
# 25           Montana
# 26           Montana
# 27        Washington
# 28             Idaho
# 29      North Dakota
#             ...
# 3055    Pennsylvania
# 3056    Pennsylvania
# 3057    Pennsylvania
# 3058    Pennsylvania
# 3059        Illinois
# 3060            Ohio
# 3061        Illinois
# 3062        Illinois
# 3063    Pennsylvania
# 3064            Ohio
# 3065         Indiana
# 3066         Indiana
# 3067         Indiana
# 3068         Indiana
# 3069         Indiana
# 3070        New York
# 3071        Virginia
# 3072        Virginia
# 3073        Virginia
# 3074        Virginia
# 3075        Virginia
# 3076        Virginia
# 3077        Virginia
# 3078        Virginia
# 3079       Wisconsin
# 3080         Arizona
# 3081      New Mexico
# 3082        Virginia
# 3083        Virginia
# 3084         Montana
# Name: STATE_NAME, Length: 3085, dtype: object

# %%
data_table.STATE_NAME == 'Arizona'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 3055    False
# 3056    False
# 3057    False
# 3058    False
# 3059    False
# 3060    False
# 3061    False
# 3062    False
# 3063    False
# 3064    False
# 3065    False
# 3066    False
# 3067    False
# 3068    False
# 3069    False
# 3070    False
# 3071    False
# 3072    False
# 3073    False
# 3074    False
# 3075    False
# 3076    False
# 3077    False
# 3078    False
# 3079    False
# 3080     True
# 3081    False
# 3082    False
# 3083    False
# 3084    False
# Name: STATE_NAME, Length: 3085, dtype: bool

# %% [markdown]
# Then, use that to filter out rows where the condition is true:

# %%
data_table[data_table.STATE_NAME == 'Arizona']
# Out:
#             NAME STATE_NAME STATE_FIPS CNTY_FIPS   FIPS  STFIPS  COFIPS  \
# 1707      Navajo    Arizona         04       017  04017       4      17
# 1708    Coconino    Arizona         04       005  04005       4       5
# 1722      Mohave    Arizona         04       015  04015       4      15
# 1726      Apache    Arizona         04       001  04001       4       1
# 2002     Yavapai    Arizona         04       025  04025       4      25
# 2182        Gila    Arizona         04       007  04007       4       7
# 2262    Maricopa    Arizona         04       013  04013       4      13
# 2311    Greenlee    Arizona         04       011  04011       4      11
# 2326      Graham    Arizona         04       009  04009       4       9
# 2353       Pinal    Arizona         04       021  04021       4      21
# 2499        Pima    Arizona         04       019  04019       4      19
# 2514     Cochise    Arizona         04       003  04003       4       3
# 2615  Santa Cruz    Arizona         04       023  04023       4      23
# 3080      La Paz    Arizona         04       012  04012       4      12
#
#       FIPSNO  SOUTH       HR60  \
# 1707    4017      0   5.263989
# 1708    4005      0   3.185449
# 1722    4015      0   0.000000
# 1726    4001      0  10.951223
# 2002    4025      0   3.458771
# 2182    4007      0   6.473749
# 2262    4013      0   6.179259
# 2311    4011      0   2.896284
# 2326    4009      0   4.746648
# 2353    4021      0  13.828390
# 2499    4019      0   5.520841
# 2514    4003      0   4.845049
# 2615    4023      0   9.252406
# 3080    4012      0   5.046682
#
#                             ...                             BLK90      GI59  \
# 1707                        ...                          0.905251  0.366863
# 1708                        ...                          1.469081  0.301222
# 1722                        ...                          0.324075  0.279339
# 1726                        ...                          0.162361  0.395913
# 2002                        ...                          0.298011  0.289509
# 2182                        ...                          0.246171  0.265294
# 2262                        ...                          3.499221  0.277828
# 2311                        ...                          0.349650  0.177691
# 2326                        ...                          1.890487  0.310256
# 2353                        ...                          3.134586  0.304294
# 2499                        ...                          3.118252  0.268266
# 2514                        ...                          5.201590  0.261208
# 2615                        ...                          0.326863  0.327130
# 3080                        ...                          2.628811  0.271556
#
#           GI69      GI79      GI89       FH60  FH70       FH80       FH90  \
# 1707  0.414135  0.401999  0.445299  13.146998  12.1  13.762783  18.033782
# 1708  0.377785  0.381655  0.403188   9.475171   8.5  11.181563  15.267643
# 1722  0.347150  0.375790  0.374383  11.508554   4.8   7.018268   9.214294
# 1726  0.450552  0.431013  0.489132  15.014738  14.6  18.727548  22.933635
# 2002  0.378195  0.376313  0.384089   9.930032   8.6   7.516372   9.483521
# 2182  0.337519  0.353848  0.386976  10.470261   8.1   9.934237  11.706102
# 2262  0.352374  0.366015  0.372756  10.642382   9.8  11.857260  14.404902
# 2311  0.257158  0.283518  0.337256   9.806115   6.7   5.295110  10.453284
# 2326  0.362926  0.383554  0.408379  11.979335  10.1  11.961367  16.129032
# 2353  0.369974  0.361193  0.400130  10.822965   8.8  10.341699  15.304144
# 2499  0.367218  0.375039  0.392144  11.381626  10.2  12.689768  16.163178
# 2514  0.359500  0.359701  0.399208  10.197573   8.7   9.912732  13.733872
# 2615  0.396807  0.393240  0.413795  19.007213  14.7  15.690913  18.272244
# 3080  0.364110  0.372662  0.405743   9.216414   8.0   9.296093  12.379134
#
#                                                geometry
# 1707  <pysal.cg.shapes.Polygon object at 0x7f7a33210...
# 1708  <pysal.cg.shapes.Polygon object at 0x7f7a33210...
# 1722  <pysal.cg.shapes.Polygon object at 0x7f7a33237...
# 1726  <pysal.cg.shapes.Polygon object at 0x7f7a33237...
# 2002  <pysal.cg.shapes.Polygon object at 0x7f7a330e4...
# 2182  <pysal.cg.shapes.Polygon object at 0x7f7a33026...
# 2262  <pysal.cg.shapes.Polygon object at 0x7f7a32ffa...
# 2311  <pysal.cg.shapes.Polygon object at 0x7f7a32fad...
# 2326  <pysal.cg.shapes.Polygon object at 0x7f7a32f55...
# 2353  <pysal.cg.shapes.Polygon object at 0x7f7a32f09...
# 2499  <pysal.cg.shapes.Polygon object at 0x7f7a32e92...
# 2514  <pysal.cg.shapes.Polygon object at 0x7f7a6c218...
# 2615  <pysal.cg.shapes.Polygon object at 0x7f7a32e0c...
# 3080  <pysal.cg.shapes.Polygon object at 0x7f7a32c59...
#
# [14 rows x 70 columns]

# %% [markdown]
# We might need this behind the scenes knowledge when we want to chain together conditions, or when we need to do spatial queries.
#
# This is because spatial queries are somewhat more complex. Let's say, for example, we want all of the counties in the US to the West of `-121` longitude. We need a way to express that question. Ideally, we want something like:
#
# ```
# SELECT
#         *
# FROM
#         data_table
# WHERE
#         x_centroid < -121
# ```

# %% [markdown]
# So, let's refer to an arbitrary polygon in the the dataframe's geometry column as `poly`. The centroid of a PySAL polygon is stored as an `(X,Y)` pair, so the longitude is the first element of the pair, `poly.centroid[0]`.
#
# Then, applying this condition to each geometry, we get the same kind of filter we used above to grab only counties in Arizona:

# %%
data_table.geometry
# Out:
# 0       <pysal.cg.shapes.Polygon object at 0x7f7a6eee1...
# 1       <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 2       <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 3       <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 4       <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 5       <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 6       <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 7       <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 8       <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 9       <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 10      <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 11      <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 12      <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 13      <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 14      <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 15      <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 16      <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 17      <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 18      <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 19      <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 20      <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 21      <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 22      <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 23      <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 24      <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 25      <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 26      <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 27      <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 28      <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 29      <pysal.cg.shapes.Polygon object at 0x7f7a33a6f...
#                               ...
# 3055    <pysal.cg.shapes.Polygon object at 0x7f7a32c46...
# 3056    <pysal.cg.shapes.Polygon object at 0x7f7a32c46...
# 3057    <pysal.cg.shapes.Polygon object at 0x7f7a32c46...
# 3058    <pysal.cg.shapes.Polygon object at 0x7f7a32c46...
# 3059    <pysal.cg.shapes.Polygon object at 0x7f7a32c46...
# 3060    <pysal.cg.shapes.Polygon object at 0x7f7a32c59...
# 3061    <pysal.cg.shapes.Polygon object at 0x7f7a32c59...
# 3062    <pysal.cg.shapes.Polygon object at 0x7f7a32c59...
# 3063    <pysal.cg.shapes.Polygon object at 0x7f7a32c59...
# 3064    <pysal.cg.shapes.Polygon object at 0x7f7a32c59...
# 3065    <pysal.cg.shapes.Polygon object at 0x7f7a32c59...
# 3066    <pysal.cg.shapes.Polygon object at 0x7f7a32c59...
# 3067    <pysal.cg.shapes.Polygon object at 0x7f7a32c59...
# 3068    <pysal.cg.shapes.Polygon object at 0x7f7a32c59...
# 3069    <pysal.cg.shapes.Polygon object at 0x7f7a32c59...
# 3070    <pysal.cg.shapes.Polygon object at 0x7f7a32c59...
# 3071    <pysal.cg.shapes.Polygon object at 0x7f7a32c59...
# 3072    <pysal.cg.shapes.Polygon object at 0x7f7a32c59...
# 3073    <pysal.cg.shapes.Polygon object at 0x7f7a32c59...
# 3074    <pysal.cg.shapes.Polygon object at 0x7f7a32c59...
# 3075    <pysal.cg.shapes.Polygon object at 0x7f7a32c59...
# 3076    <pysal.cg.shapes.Polygon object at 0x7f7a32c59...
# 3077    <pysal.cg.shapes.Polygon object at 0x7f7a32c59...
# 3078    <pysal.cg.shapes.Polygon object at 0x7f7a32c59...
# 3079    <pysal.cg.shapes.Polygon object at 0x7f7a32c59...
# 3080    <pysal.cg.shapes.Polygon object at 0x7f7a32c59...
# 3081    <pysal.cg.shapes.Polygon object at 0x7f7a32c59...
# 3082    <pysal.cg.shapes.Polygon object at 0x7f7a32c59...
# 3083    <pysal.cg.shapes.Polygon object at 0x7f7a32c59...
# 3084    <pysal.cg.shapes.Polygon object at 0x7f7a32c59...
# Name: geometry, Length: 3085, dtype: object

# %%
data_table.geometry.apply(lambda x: x.centroid[0] < -121)\
                   .head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: geometry, dtype: bool

# %% [markdown]
# If we use this as a filter on the table, we can get only the rows that match that condition, just like we did for the `STATE_NAME` query:

# %%
data_table[data_table.geometry.apply(lambda x: x.centroid[0] < -119)].head()
# Out:
#         NAME  STATE_NAME STATE_FIPS CNTY_FIPS   FIPS  STFIPS  COFIPS  FIPSNO  \
# 3   Okanogan  Washington         53       047  53047      53      47   53047
# 27   Whatcom  Washington         53       073  53073      53      73   53073
# 31    Skagit  Washington         53       057  53057      53      57   53057
# 42    Chelan  Washington         53       007  53007      53       7   53007
# 44   Clallam  Washington         53       009  53009      53       9   53009
#
#     SOUTH      HR60                        ...                          \
# 3       0  2.612330                        ...
# 27      0  1.422131                        ...
# 31      0  2.596560                        ...
# 42      0  4.908698                        ...
# 44      0  3.330891                        ...
#
#        BLK90      GI59      GI69      GI79      GI89      FH60  FH70  \
# 3   0.155922  0.258540  0.371218  0.381240  0.394519  9.039900   8.1
# 27  0.508687  0.247630  0.346935  0.369436  0.358418  9.174415   7.1
# 31  0.351958  0.239346  0.344830  0.364623  0.362265  8.611518   7.9
# 42  0.153110  0.246292  0.367681  0.374505  0.383486  8.787907   8.1
# 44  0.568504  0.240573  0.349320  0.361619  0.366854  8.788882   6.5
#
#          FH80       FH90                                           geometry
# 3   10.084926  12.840340  <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 27   9.718054  11.135022  <pysal.cg.shapes.Polygon object at 0x7f7a33a62...
# 31  10.480031  11.382484  <pysal.cg.shapes.Polygon object at 0x7f7a33a6f...
# 42   9.968454  12.236493  <pysal.cg.shapes.Polygon object at 0x7f7a33a6f...
# 44   9.660900  12.281690  <pysal.cg.shapes.Polygon object at 0x7f7a33a6f...
#
# [5 rows x 70 columns]

# %%
len(data_table[data_table.geometry.apply(lambda x: x.centroid[0] < -119)]) #how many west of -119?
# Out:
# 109

# %% [markdown]
# ## Other types of spatial queries
#
# Everybody knows the following statements are true:
#
# 1. If you head directly west from Reno, Nevada, you will shortly enter California.
# 2. San Diego is in California.
#
# But what does this tell us about the location of San Diego relative to Reno?
#
# Or for that matter, how many counties in California are to the east of Reno?

# %%
geom = data_table.query('(NAME == "Washoe") & (STATE_NAME == "Nevada")').geometry
geom
# Out:
# 605    <pysal.cg.shapes.Polygon object at 0x7f7a3383e...
# Name: geometry, dtype: object

# %%
lon,lat = geom.values[0].centroid

# %%
lon
# Out:
# -119.6555030699793

# %%
cal_counties = data_table.query('(STATE_NAME=="California")')

# %%
cal_counties[cal_counties.geometry.apply(lambda x: x.centroid[0] > lon)]
# Out:
#                 NAME  STATE_NAME STATE_FIPS CNTY_FIPS   FIPS  STFIPS  COFIPS  \
# 1312            Mono  California         06       051  06051       6      51
# 1591          Fresno  California         06       019  06019       6      19
# 1620            Inyo  California         06       027  06027       6      27
# 1765          Tulare  California         06       107  06107       6     107
# 1956            Kern  California         06       029  06029       6      29
# 1957  San Bernardino  California         06       071  06071       6      71
# 2117         Ventura  California         06       111  06111       6     111
# 2255       Riverside  California         06       065  06065       6      65
# 2279          Orange  California         06       059  06059       6      59
# 2344       San Diego  California         06       073  06073       6      73
# 2351     Los Angeles  California         06       037  06037       6      37
# 2358        Imperial  California         06       025  06025       6      25
#
#       FIPSNO  SOUTH       HR60  \
# 1312    6051      0  15.062509
# 1591    6019      0   5.192037
# 1620    6027      0   8.558713
# 1765    6107      0   3.364944
# 1956    6029      0   6.393044
# 1957    6071      0   3.243373
# 2117    6111      0   3.180374
# 2255    6065      0   4.898903
# 2279    6059      0   2.083555
# 2344    6073      0   2.387842
# 2351    6037      0   4.564947
# 2358    6025      0   4.160599
#
#                             ...                              BLK90      GI59  \
# 1312                        ...                           0.431900  0.229888
# 1591                        ...                           5.007266  0.286651
# 1620                        ...                           0.432143  0.242293
# 1765                        ...                           1.480503  0.303303
# 1956                        ...                           5.544117  0.273083
# 1957                        ...                           8.103188  0.259038
# 2117                        ...                           2.336118  0.259643
# 2255                        ...                           5.433210  0.284000
# 2279                        ...                           1.770587  0.255864
# 2344                        ...                           6.377301  0.269147
# 2351                        ...                          11.203381  0.267207
# 2358                        ...                           2.398836  0.286568
#
#           GI69      GI79      GI89       FH60  FH70       FH80       FH90  \
# 1312  0.327520  0.388414  0.366316   6.743421   6.6   8.187135  10.083699
# 1591  0.379884  0.394981  0.412947  11.788963  11.8  13.998747  18.523541
# 1620  0.334361  0.353784  0.378516   9.676365   8.1   8.480065  12.067279
# 1765  0.380229  0.395059  0.410811  10.398757   9.5  11.957928  16.303423
# 1956  0.364603  0.380617  0.395393  10.225236  10.4  12.037755  16.118827
# 1957  0.350927  0.362389  0.372659   9.857519  10.0  12.999831  15.403925
# 2117  0.325908  0.350430  0.329175  10.304761   8.9  11.047165  12.044930
# 2255  0.376737  0.383226  0.368177   9.769959   9.2  11.145612  12.678340
# 2279  0.316731  0.355117  0.330447   8.802545   9.1  12.405423  12.974648
# 2344  0.352428  0.382815  0.368301  11.425041  11.5  14.384523  15.489702
# 2351  0.353837  0.402031  0.392669  13.071850  13.4  17.767317  18.808224
# 2358  0.374913  0.397430  0.426348  11.466417   9.7  12.590249  17.243741
#
#                                                geometry
# 1312  <pysal.cg.shapes.Polygon object at 0x7f7a333fb...
# 1591  <pysal.cg.shapes.Polygon object at 0x7f7a332a0...
# 1620  <pysal.cg.shapes.Polygon object at 0x7f7a3324a...
# 1765  <pysal.cg.shapes.Polygon object at 0x7f7a331e0...
# 1956  <pysal.cg.shapes.Polygon object at 0x7f7a33113...
# 1957  <pysal.cg.shapes.Polygon object at 0x7f7a33113...
# 2117  <pysal.cg.shapes.Polygon object at 0x7f7a3305f...
# 2255  <pysal.cg.shapes.Polygon object at 0x7f7a32ffa...
# 2279  <pysal.cg.shapes.Polygon object at 0x7f7a32ffa...
# 2344  <pysal.cg.shapes.Polygon object at 0x7f7a32f55...
# 2351  <pysal.cg.shapes.Polygon object at 0x7f7a32f55...
# 2358  <pysal.cg.shapes.Polygon object at 0x7f7a32f09...
#
# [12 rows x 70 columns]

# %%
len(cal_counties)
# Out:
# 58

# %% [markdown]
# This works on any type of spatial query.
#
# For instance, if we wanted to find all of the counties that are within a threshold distance from an observation's centroid, we can do it in the following way.
#
# But first, we need to handle distance calculations on the earth's surface.

# %%
from math import radians, sin, cos, sqrt, asin

def gcd(loc1, loc2, R=3961):
    """Great circle distance via Haversine formula
    
    Parameters
    ----------
    
    loc1: tuple (long, lat in decimal degrees)
    
    loc2: tuple (long, lat in decimal degrees)
    
    R: Radius of the earth (3961 miles, 6367 km)
    
    Returns
    -------
    great circle distance between loc1 and loc2 in units of R
    
    
    Notes
    ------
    Does not take into account non-spheroidal shape of the Earth
    
    
    
    >>> san_diego = -117.1611, 32.7157
    >>> austin = -97.7431, 30.2672
    >>> gcd(san_diego, austin)
    1155.474644164695
  
    
    """
    lon1, lat1 = loc1
    lon2, lat2 = loc2
    dLat = radians(lat2 - lat1)
    dLon = radians(lon2 - lon1)
    lat1 = radians(lat1)
    lat2 = radians(lat2)
 
    a = sin(dLat/2)**2 + cos(lat1)*cos(lat2)*sin(dLon/2)**2
    c = 2*asin(sqrt(a))

    return R * c
 
def gcdm(loc1, loc2):
    return gcd(loc1, loc2)

def gcdk(loc1, loc2):
    return gcd(loc1, loc2, 6367 )

# %%
san_diego = -117.1611, 32.7157
austin = -97.7431, 30.2672
gcd(san_diego, austin)
# Out:
# 1155.474644164695

# %%
gcdk(san_diego, austin)
# Out:
# 1857.3357887898544

# %%
loc1 = (-117.1611, 0.0)
loc2 = (-118.1611, 0.0)
gcd(loc1, loc2)
# Out:
# 69.13249167149539

# %%
loc1 = (-117.1611, 45.0)
loc2 = (-118.1611, 45.0)
gcd(loc1, loc2)
# Out:
# 48.88374342930467

# %%
loc1 = (-117.1611, 89.0)
loc2 = (-118.1611, 89.0)
gcd(loc1, loc2)
# Out:
# 1.2065130336642724

# %%
lats = range(0, 91)
onedeglon = [ gcd((-117.1611,lat),(-118.1611,lat)) for lat in lats]

# %%
onedeglon
# Out:
# [69.13249167149539,
#  69.12196219093418,
#  69.09037695736484,
#  69.03774559415092,
#  68.96408413696794,
#  68.8694150289087,
#  68.75376711363286,
#  68.61717562656312,
#  68.45968218413029,
#  68.28133477107086,
#  68.08218772578115,
#  67.86230172373226,
#  67.62174375895108,
#  67.36058712357318,
#  67.07891138547394,
#  66.77680236398466,
#  66.45435210370128,
#  66.11165884639415,
#  65.7488270010266,
#  65.36596711189303,
#  64.96319582488495,
#  64.54063585189635,
#  64.09841593337912,
#  63.63667079905998,
#  63.15554112683134,
#  62.65517349982861,
#  62.13572036170711,
#  61.597339970132836,
#  61.04019634850107,
#  60.46445923589779,
#  59.87030403531951,
#  59.257911760167296,
#  58.62746897903174,
#  57.97916775878565,
#  57.313205606002136,
#  56.62978540671627,
#  55.92911536454842,
#  55.211408937209065,
#  54.4768847714038,
#  53.72576663615924,
#  52.9582833545899,
#  52.17466873412728,
#  51.375161495232426,
#  50.56000519861397,
#  49.72944817097405,
#  48.88374342930467,
#  48.023148603757974,
#  47.14792585911406,
#  46.25834181487017,
#  45.35466746397604,
#  44.43717809024016,
#  43.5061531844322,
#  42.56187635910738,
#  41.604635262178775,
#  40.63472148926384,
#  39.652430494832416,
#  38.65806150218264,
#  37.65191741227306,
#  36.634304711437984,
#  35.605533378014954,
#  34.56591678791226,
#  33.51577161914559,
#  32.455417755372906,
#  31.38517818845674,
#  30.305378920083772,
#  29.21634886247161,
#  28.11841973819288,
#  27.011925979147257,
#  25.89720462471205,
#  24.77459521910236,
#  23.6444397079719,
#  22.507082334286167,
#  21.362869533499236,
#  20.21214982806623,
#  19.055273721323466,
#  17.892593590768424,
#  16.724463580771936,
#  15.551239494755208,
#  14.373278686864246,
#  13.190939953174624,
#  12.004583422459604,
#  10.814570446554605,
#  9.621263490351305,
#  8.425026021454727,
#  7.226222399536701,
#  6.025217765419218,
#  4.822377929921292,
#  3.6180692625029747,
#  2.4126585797401763,
#  1.2065130336642724,
#  4.233090503605412e-15]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(lats, onedeglon)
plt.ylabel('miles')
plt.xlabel('degree of latitude')
plt.title('Length of a degree of longitude')
# Out:
# Text(0.5,1,'Length of a degree of longitude')

# %%
san_diego = -117.1611, 32.7157
austin = -97.7431, 30.2672
gcd(san_diego, austin)
# Out:
# 1155.474644164695

# %% [markdown]
# Now we can use our distance function to pose distance-related queries on our data table.

# %%
# Find all the counties with centroids within 50 miles of Austin
def near_target_point(polygon, target=austin, threshold=50):
    return gcd(polygon.centroid, target) < threshold 

data_table[data_table.geometry.apply(near_target_point)]
# Out:
#             NAME STATE_NAME STATE_FIPS CNTY_FIPS   FIPS  STFIPS  COFIPS  \
# 2698      Burnet      Texas         48       053  48053      48      53
# 2716  Williamson      Texas         48       491  48491      48     491
# 2742      Travis      Texas         48       453  48453      48     453
# 2751         Lee      Texas         48       287  48287      48     287
# 2754      Blanco      Texas         48       031  48031      48      31
# 2762     Bastrop      Texas         48       021  48021      48      21
# 2769        Hays      Texas         48       209  48209      48     209
# 2795    Caldwell      Texas         48       055  48055      48      55
# 2798       Comal      Texas         48       091  48091      48      91
# 2808   Guadalupe      Texas         48       187  48187      48     187
#
#       FIPSNO  SOUTH      HR60  \
# 2698   48053      1  0.000000
# 2716   48491      1  9.511852
# 2742   48453      1  4.242561
# 2751   48287      1  7.449622
# 2754   48031      1  0.000000
# 2762   48021      1  3.938946
# 2769   48209      1  5.016555
# 2795   48055      1  9.677544
# 2798   48091      1  3.359538
# 2808   48187      1  5.743759
#
#                             ...                              BLK90      GI59  \
# 2698                        ...                           1.186224  0.327508
# 2716                        ...                           4.916482  0.363603
# 2742                        ...                          10.959791  0.299292
# 2751                        ...                          13.847829  0.376002
# 2754                        ...                           0.937709  0.369814
# 2762                        ...                          11.792071  0.370264
# 2769                        ...                           3.383424  0.385061
# 2795                        ...                          10.704001  0.380080
# 2798                        ...                           0.854684  0.274182
# 2808                        ...                           5.649500  0.340374
#
#           GI69      GI79      GI89       FH60  FH70       FH80       FH90  \
# 2698  0.449285  0.385079  0.405890  10.774142   6.5   7.115629  10.568742
# 2716  0.379902  0.341976  0.345201  13.532731   9.0   7.582572  12.032589
# 2742  0.372293  0.378953  0.388149  12.976379  10.9  14.459691  17.307113
# 2751  0.433132  0.394000  0.394959  12.305699  10.1   8.875542  10.530896
# 2754  0.436449  0.394609  0.394414   9.365854   6.0   8.074074   9.080119
# 2762  0.419933  0.390927  0.380907  14.747191  12.5  10.559006  12.281387
# 2769  0.424973  0.378992  0.372266  13.064187   9.4  10.003691  10.337188
# 2795  0.412614  0.410802  0.413940  15.229616  10.5  12.894034  17.191502
# 2798  0.359174  0.375810  0.380032  11.315107   7.6   8.693149   9.104427
# 2808  0.388821  0.354559  0.378073  11.758921   9.6  10.418149  12.918448
#
#                                                geometry
# 2698  <pysal.cg.shapes.Polygon object at 0x7f7a32de2...
# 2716  <pysal.cg.shapes.Polygon object at 0x7f7a32d8a...
# 2742  <pysal.cg.shapes.Polygon object at 0x7f7a32db3...
# 2751  <pysal.cg.shapes.Polygon object at 0x7f7a32db3...
# 2754  <pysal.cg.shapes.Polygon object at 0x7f7a32db3...
# 2762  <pysal.cg.shapes.Polygon object at 0x7f7a32db3...
# 2769  <pysal.cg.shapes.Polygon object at 0x7f7a32db3...
# 2795  <pysal.cg.shapes.Polygon object at 0x7f7a32d5d...
# 2798  <pysal.cg.shapes.Polygon object at 0x7f7a32d5d...
# 2808  <pysal.cg.shapes.Polygon object at 0x7f7a32d09...
#
# [10 rows x 70 columns]

# %% [markdown]
# ### Moving in and out of the dataframe

# %% [markdown]
# Most things in PySAL will be explicit about what type their input should be. Most of the time, PySAL functions require either lists or arrays. This is why the file-handler methods are the default IO method in PySAL: the rest of the computational tools are built around their datatypes.
#
# However, it is very easy to get the correct datatype from Pandas using the `values` and `tolist` commands.
#
# `tolist()` will convert its entries to a list. But, it can only be called on individual columns (called `Series` in `pandas` documentation).
#
# So, to turn the `NAME` column into a list:

# %%
data_table.NAME.tolist()[0:10]
# Out:
# ['Lake of the Woods',
#  'Ferry',
#  'Stevens',
#  'Okanogan',
#  'Pend Oreille',
#  'Boundary',
#  'Lincoln',
#  'Flathead',
#  'Glacier',
#  'Toole']

# %% [markdown]
# To extract many columns, you must select the columns you want and call their `.values` attribute.
#
# If we were interested in grabbing all of the `HR` variables in the dataframe, we could first select those column names:

# %%
HRs = [col for col in data_table.columns if col.startswith('HR')]
HRs
# Out:
# ['HR60', 'HR70', 'HR80', 'HR90']

# %% [markdown]
# We can use this to focus only on the columns we want:

# %%
data_table[HRs].head()
# Out:
#        HR60      HR70       HR80       HR90
# 0  0.000000  0.000000   8.855827   0.000000
# 1  0.000000  0.000000  17.208742  15.885624
# 2  1.863863  1.915158   3.450775   6.462453
# 3  2.612330  1.288643   3.263814   6.996502
# 4  0.000000  0.000000   7.770008   7.478033

# %% [markdown]
# With this, calling `.values` gives an array containing all of the entries in this subset of the table:

# %%
data_table[['HR90', 'HR80']].values
# Out:
# array([[ 0.        ,  8.85582713],
#        [15.88562351, 17.20874204],
#        [ 6.46245315,  3.4507747 ],
#        ...,
#        [ 4.36732988,  5.2803488 ],
#        [ 3.72771194,  3.00003   ],
#        [ 2.04885495,  1.19474313]])

# %% [markdown]
# Using the PySAL pdio tools means that if you're comfortable with working in Pandas, you can continue to do so.
#
# If you're more comfortable using Numpy or raw Python to do your data processing, PySAL's IO tools naturally support this.

# %% [markdown]
# ## Exercises
#
# 1. Find the county with the western most centroid that is within 1000 miles of Austin.
# 2. Find the distance between Austin and that centroid.

# %% [markdown]
# ## Solutions

# %%
austin_lon = austin[0]
west = data_table[data_table.geometry.apply(lambda x: x.centroid[0] < austin_lon)]

# %%
def near_target_point(polygon, target=austin, threshold=1000):
    return gcd(polygon.centroid, target) <= threshold 

west_lt_1000 = west[west.geometry.apply(near_target_point)]

# %%
maxd = 0.
county = None
for i,row in west_lt_1000.iterrows():
    d = gcd(row['geometry'].centroid, austin)
    if d > maxd:
        county = row['NAME']
        state = row['STATE_NAME']
        maxd = d

print('Centroid of %s, %s is %f miles west of Austin'%(county, state, maxd))
